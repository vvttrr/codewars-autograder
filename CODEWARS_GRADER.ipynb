# %% [markdown]
# ## GRADING BOT

# %%
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

# new thing we are importing, make sure this is imported
from lxml import etree

# %%
###### Import Pandas

# %%
## Paste in your chrome application file location, see above if you don't know how to do it.
chrome_path = 'open -a /Applications/Google\ Chrome.app %s'

## saving options as 
options = webdriver.ChromeOptions()

## Paste in your driver file location
driver_location = r'./chromedriver'

## SYNTAX: webdriver.Chrome(executable_path = "driver_file_path", options=options)
driver = webdriver.Chrome(
    executable_path = driver_location,
    options = options)

# %%
#time.sleep(3)

## save the url that you would like to go to as a string variable
# Don't forget "https://"
url = "https://www.codewars.com/users/vgoncalves"

url2 = "https://earth.google.com"

driver.get(url2)

time.sleep(3)

# %%
search = driver.find_element(By.CSS_SELECTOR, '[id=search]')

# %%
searchbox = driver.find_element_by_xpath('//earth-gm2-icon-button[@id="search"]')
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 searchbox = driver.find_element_by_xpath('//earth-gm2-icon-button[@id="search"]')
#
# File ~/opt/anaconda3/envs/Selenium/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:394, in WebDriver.find_element_by_xpath(self, xpath)
#     378 def find_element_by_xpath(self, xpath):
#     379     """
#     380     Finds an element by xpath.
#     381
#    (...)
#     392         element = driver.find_element_by_xpath('//div/td[1]')
#     393     """
# --> 394     return self.find_element(by=By.XPATH, value=xpath)
#
# File ~/opt/anaconda3/envs/Selenium/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:976, in WebDriver.find_element(self, by, value)
#     974         by = By.CSS_SELECTOR
#     975         value = '[name="%s"]' % value
# ...

# %%
search.click()
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 search.click()
#
# File ~/opt/anaconda3/envs/Selenium/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:80, in WebElement.click(self)
#      78 def click(self):
#      79     """Clicks the element."""
# ---> 80     self._execute(Command.CLICK_ELEMENT)
#
# File ~/opt/anaconda3/envs/Selenium/lib/python3.10/site-packages/selenium/webdriver/remote/webelement.py:633, in WebElement._execute(self, command, params)
#     631     params = {}
#     632 params['id'] = self._id
# --> 633 return self._parent.execute(command, params)
#
# File ~/opt/anaconda3/envs/Selenium/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:321, in WebDriver.execute(self, driver_command, params)
#     319 response = self.command_executor.execute(driver_command, params)
# ...
